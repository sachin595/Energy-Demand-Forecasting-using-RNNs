# %% [markdown]
# # **PART II-A : 1-input predictor for a 3-hour horizon**

# %% [markdown]
# # dataset
# **Retrieving the  GEFCom2014 (E, V2) Data**
#
# The data in this project is taken from the GEFCom2014 forecasting competition. It consists of hourly electricity load ("eload") and temperature ("tempf") values for a USA city. *italicized text*
# The data will be brought into the Colab session from an internet repository, aand the extracted Ecel file will be used to create a comma-seprated-value (csv) text file, similar to the one in Chapter 10 of te textbook.

# %%
import numpy as np 
import pandas as pd
import os
import shutil
import matplotlib.pyplot as plt
# from common.utils import load_data, extract_data, download_file
# %matplotlib inline

# !wget https://mlftsfwp.blob.core.windows.net/mlftsfwp/GEFCom2014.zip
# !wget https://www.dropbox.com/s/pqenrr2mcvl0hk9/GEFCom2014.zip
# Out:
# --2023-04-28 14:14:45--  https://www.dropbox.com/s/pqenrr2mcvl0hk9/GEFCom2014.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.3.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.3.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/pqenrr2mcvl0hk9/GEFCom2014.zip [following]
# --2023-04-28 14:14:45--  https://www.dropbox.com/s/raw/pqenrr2mcvl0hk9/GEFCom2014.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com/cd/0/inline/B7CTMzLN8pzM2FyeFV63aJJBx0LLSQdcDghvqnqWbkYcVzEmQRljiEYbiThmBYFSh7QxulA_CN4oEk4sloKnzYnqrgeGqewC6Cl3JZpaNWIA33FsaOCmEtt15Ne9Z-ihV4jXiu2gXmCrSeg5NAeye4LimVpa3mFpvYJqnbZpE2eozQ/file# [following]
# --2023-04-28 14:14:45--  https://uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com/cd/0/inline/B7CTMzLN8pzM2FyeFV63aJJBx0LLSQdcDghvqnqWbkYcVzEmQRljiEYbiThmBYFSh7QxulA_CN4oEk4sloKnzYnqrgeGqewC6Cl3JZpaNWIA33FsaOCmEtt15Ne9Z-ihV4jXiu2gXmCrSeg5NAeye4LimVpa3mFpvYJqnbZpE2eozQ/file
# Resolving uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com (uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com (uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/B7C3_zkjyhEt1RsWUnG4IwgfpbobinwFjRbwsamG0CSUrosurfTCIFKVU5bx7xRRX3empX1Q7hKHTSIW7AEU2eQOoiIpaXkHElh1-a8f8F3CtQRj78l_DF98FgfeFyOb6yp3-R-DqPUhIoXKGJaUAkTinQ-zrsHhE_2xMaaviAkbJ9ulrBJ6bZ470CdYaqSz1A35oL0-7jgDtpxqQNMz308QigXCGXAaWSCgUNpiZ3g9Do5S8qeOU91q0nhNxyxRyAUjhSMf575e6Z3ZB4mxLvJux20RhOsfTNp6g_WCzRm2eFAPADVcRydI4nJCNQOAORL32zvofy4SY3wjBNUW7xDhcBtDKYU0C8Q47Jl_m5Zno7M9scTXFm0CO4njE5MxAg_Na-Wy4bsJBMkLEjHu4lEWAjD8uYH8l96DQJhnxFUcZw/file [following]
# --2023-04-28 14:14:46--  https://uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com/cd/0/inline2/B7C3_zkjyhEt1RsWUnG4IwgfpbobinwFjRbwsamG0CSUrosurfTCIFKVU5bx7xRRX3empX1Q7hKHTSIW7AEU2eQOoiIpaXkHElh1-a8f8F3CtQRj78l_DF98FgfeFyOb6yp3-R-DqPUhIoXKGJaUAkTinQ-zrsHhE_2xMaaviAkbJ9ulrBJ6bZ470CdYaqSz1A35oL0-7jgDtpxqQNMz308QigXCGXAaWSCgUNpiZ3g9Do5S8qeOU91q0nhNxyxRyAUjhSMf575e6Z3ZB4mxLvJux20RhOsfTNp6g_WCzRm2eFAPADVcRydI4nJCNQOAORL32zvofy4SY3wjBNUW7xDhcBtDKYU0C8Q47Jl_m5Zno7M9scTXFm0CO4njE5MxAg_Na-Wy4bsJBMkLEjHu4lEWAjD8uYH8l96DQJhnxFUcZw/file
# Reusing existing connection to uc9c793d6b5b48e96dd1c0e87a65.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126360077 (121M) [application/zip]
# Saving to: ‘GEFCom2014.zip’
#
# GEFCom2014.zip      100%[===================>] 120.51M  97.3MB/s    in 1.2s
#
# 2023-04-28 14:14:48 (97.3 MB/s) - ‘GEFCom2014.zip’ saved [126360077/126360077]

# %%
# !ls -l 
# !unzip GEFCom2014.zip
# Out:
# Archive:  GEFCom2014.zip
#    creating: GEFCom2014 Data/
#  extracting: GEFCom2014 Data/GEFCom2014-S_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-W_V2.zip
#   inflating: GEFCom2014 Data/READ ME_V2.txt
#   inflating: GEFCom2014 Data/Provisional_Leaderboard_V2.xlsx
#  extracting: GEFCom2014 Data/GEFCom2014-L_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-E_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-P_V2.zip

# %%
# !ls -l
# Out:
# total 123408
# drwxrwxr-x 2 root root      4096 Feb 11  2016 'GEFCom2014 Data'
# -rw-r--r-- 1 root root 126360077 Apr 28 14:14  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %%
# !ls -l 'GEFCom2014 Data'/
# Out:
# total 123420
# -rw-rw-r-- 1 root root  2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-rw-r-- 1 root root  2599214 Feb 11  2016  GEFCom2014-L_V2.zip
# -rw-rw-r-- 1 root root  3338992 Feb 11  2016  GEFCom2014-P_V2.zip
# -rw-rw-r-- 1 root root 36734790 Feb 11  2016  GEFCom2014-S_V2.zip
# -rw-rw-r-- 1 root root 81149634 Feb 11  2016  GEFCom2014-W_V2.zip
# -rw-rw-r-- 1 root root   195932 Feb 11  2016  Provisional_Leaderboard_V2.xlsx
# -rw-rw-r-- 1 root root      389 Feb 11  2016 'READ ME_V2.txt'

# %% [markdown]
# ** We are interested in GEFCom2014-E_V2.zip**

# %%
# Let's bring it to the top level before unzipping it
# !mv  'GEFCom2014 Data'/GEFCom2014-E_V2.zip  ./

# %%
# !unzip GEFCom2014-E_V2.zip
# Out:
# Archive:  GEFCom2014-E_V2.zip
#   inflating: GEFCom2014-E.xlsx

# %%
# We can now verify that we hot the file GEFCom2014-E.xlsx
# !ls -l
# Out:
# total 128100
# drwxrwxr-x 2 root root      4096 Apr 28 14:15 'GEFCom2014 Data'
# -rw-rw-r-- 1 root root   2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-r--r-- 1 root root   2452214 Jan 25  2016  GEFCom2014-E.xlsx
# -rw-r--r-- 1 root root 126360077 Apr 28 14:14  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %% [markdown]
# ***We have GEFCom2014-E.xlsx***

# %% [markdown]
# This script will "translate" the .xlsx file to a .cvs file, so that the initial situation is the same as for the Jena temperature example from Chapter 10 of textbook - IN THIS PROCESS WE WILL ALSO REMOVE THE MLTIPLE INITIAL LINES THAT DO NOT HAVE LOAD VALUES (this is done through the "skip_rows" parameter)

# %%
# CONVERT GEFCom2014-E.xlsx to a PANDAS DATAFRAME called GEFDF
# import pandas as pd

GEFDF = pd.read_excel('GEFCom2014-E.xlsx', skiprows=range(1, 17545), dtype = {'A':np.int32  ,'B':np.int8   ,'C':np.int32  ,'D':np.float64}, index_col = None )

# %%
# We can "see" the Pandas DataFrame (called GEFDF) that has been obtained
print(GEFDF)
# Out:
#             Date  Hour    load          T
# 0     2006-01-01     1  3010.0  22.666667
# 1     2006-01-01     2  2853.0  20.666667
# 2     2006-01-01     3  2758.0  21.333333
# 3     2006-01-01     4  2705.0  19.000000
# 4     2006-01-01     5  2709.0  19.333333
# ...          ...   ...     ...        ...
# 78883 2014-12-31    20  4012.0  18.000000
# 78884 2014-12-31    21  3856.0  16.666667
# 78885 2014-12-31    22  3671.0  17.000000
# 78886 2014-12-31    23  3499.0  15.333333
# 78887 2014-12-31    24  3345.0  15.333333
#
# [78888 rows x 4 columns]

# %%
# Now writing out the GEFDF dataframe to a text (csv) file
GEFDF.to_csv('GEF14.csv',  encoding='utf-8', index=False, header=True, columns=['Hour','load','T'],line_terminator='\n' )
with open('GEF14.csv') as f:
    lines = f.readlines()
    last = len(lines) - 1
    lines[last] = lines[last].replace('\r','').replace('\n','')
with open('GEF14.csv', 'w') as wr:
    wr.writelines(lines)
# Out:
# <ipython-input-15-95d21a26e29b>:2: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   GEFDF.to_csv('GEF14.csv',  encoding='utf-8', index=False, header=True, columns=['Hour','load','T'],line_terminator='\n' )

# %%
# verifying we have created the csv file GEF14.csv
# !ls -l ./
# Out:
# total 129640
# -rw-r--r-- 1 root root   1573348 Apr 28 14:15  GEF14.csv
# drwxrwxr-x 2 root root      4096 Apr 28 14:15 'GEFCom2014 Data'
# -rw-rw-r-- 1 root root   2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-r--r-- 1 root root   2452214 Jan 25  2016  GEFCom2014-E.xlsx
# -rw-r--r-- 1 root root 126360077 Apr 28 14:14  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %% [markdown]
# From this point onwards, the preparation is similar as for the Jena temperature prediction case from the book but the columns in this file are just:

# %% [markdown]
# hour( 1 to 24) ; LOAD (e.g., 4012.0 ) ; TEMP (in oF ,  e.g., 86.5)

# %% [markdown]
# **Inspecting the data of the GEFC14.csv FILE**

# %% [markdown]
# This will separate the heade from the rest, whicj will be kept in "lines"

# %%
# THIS CODE CELL IS ESSENTIALLY THE SAME AS IN THE EXAMPLE FROM CH. 10 IN BOOK
import os
fname = os.path.join("GEF14.csv")

with open(fname) as f:
    data = f.read()

lines = data.split("\n")
header = lines[0].split(",")
lines = lines[1:]
print(header)
print(len(lines))
# Out:
# ['Hour', 'load', 'T']
# 78888

# %% [markdown]
# **Parsing the data**

# %% [markdown]
# We will separate temperatures in tempf, loads in eload and both in raw_data (Hour will be ignored)

# %%
# VERY SIMILAR TO THE CORRESPONDING C0DE CELL FROM CHAPTER 10 IN BOOK
# eload (electric load) is the timeseries we will predict
# tempf (temperature in Fahrenheit) is the temperature at the same time
# import numpy as np
eload = np.zeros((len(lines),))
tempf = np.zeros((len(lines),))
data= raw_data = np.zeros((len(lines), len(header)-2))   #chgd )-1  to )-2 to also
# remove the HOUR column, in addition to the DATE column
data2 = raw_data2 = np.zeros((len(lines), 2))
print(len(lines))

for m in range(78888):
    thisline  = lines[m]
    values = [float(x) for x in thisline.split(",")[1:]]
    eload[m] = values[0]         #Captures JUST E LOAD
    tempf[m] = values[1]            #Captures JUST TEMPF
    raw_data[m] = values[0]         #Like this, raw_data Captures JUST E LOAD
    raw_data2[m, :] = values[:]   # Like this, raw_data CAPTURES BOTH inputs
# Out:
# 78888

# %% [markdown]
# **Plotting the eload timeseries**

# %%
from matplotlib import pyplot as plt
plt.plot(range(len(eload)), eload)

# %%
plt.plot(range(len(tempf)), tempf)

# %% [markdown]
# **THIS IS THE BEGINNING OF THE ACTUAL SOLUTION**

# %% [markdown]
# **Computing the number of samples we'll use for each data split**

# %%
num_train_samples = int(0.5 * len(raw_data))
num_val_samples = int(0.25 * len(raw_data))
num_test_samples = len(raw_data) - num_train_samples - num_val_samples
print("num_train_samples:", num_train_samples)
print("num_val_samples:", num_val_samples)
print("num_test_samples:", num_test_samples)
# Out:
# num_train_samples: 39444
# num_val_samples: 19722
# num_test_samples: 19722

# %% [markdown]
# ### Preparing the data

# %%
# Display the ELOAD for the first 10 days
plt.plot(range(240),eload[:240])

# %%
# Display the tempf for the first 10 days
plt.plot(range(240),tempf[:240])

# %% [markdown]
# **Normalizing the data**

# %%
mean = raw_data[:num_train_samples].mean(axis=0)
raw_data -= mean
std = raw_data[:num_train_samples].std(axis=0)
raw_data /= std

# %%
mean
# Out:
# array([3310.41855542])

# %%
std
# Out:
# array([585.83380329])

# %% [markdown]
# # Instantiating datasets for training, validation, and testing for 3 hour one input

# %%
# LETS JUST USE ELOAD TO FORECAST ELOAD
# THIS TIME, ( 1-input case)
from tensorflow import keras

horizon = 3       # Num. of hours ahead for forecast
sampling_rate = 1
sequence_length = 12
delay = sampling_rate * (sequence_length + horizon - 1) 
batch_size = 128

train_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],    
    targets=raw_data[delay:], # This would used "Normalized Targets"
   # targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,                  #changed to false JUST FOR VERIF
    batch_size= num_train_samples,
    start_index=0,
    end_index=num_train_samples)

val_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],    # changed from raw_data to just eload not really
    targets=raw_data[delay:],  # This would used "Normalized Targets"
    #targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=num_val_samples,
    start_index=num_train_samples,
    end_index=num_train_samples + num_val_samples)

test_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],     # changed from raw_data to just eload
    targets=raw_data[delay:],  # This would used "Normalized Targets"
    #targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=False,
    batch_size=num_test_samples,
    start_index=num_train_samples + num_val_samples)

# %%
max_eload=0
min_eload=np.inf
for x, y in test_dataset:
    eload_values = y  # extract the eload values from the target array
    max_eload_in_batch = np.max(eload_values)
    if max_eload_in_batch > max_eload:
      max_eload = max_eload_in_batch

    min_eload_in_batch = np.min(eload_values)
    if min_eload_in_batch < min_eload:
        min_eload = min_eload_in_batch

full_range_eload = max_eload - min_eload


print("Max eload in the test set: ", max_eload)

print("Min eload in the test set: ", min_eload)

print("Full range of eload in the test set: ", full_range_eload)
# Out:
# Max eload in the test set:  3.266423743130643
# Min eload in the test set:  -2.2726898788595946
# Full range of eload in the test set:  5.5391136219902375

# %%
for samples, targets in train_dataset:
    print("train dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
for samples, targets in test_dataset:
    print("test dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
for samples, targets in val_dataset:
    print("val dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
# Out:
# train dataset:
# samples shape: (39433, 12, 1)
# targets shape: (39433, 1)
# test dataset:
# samples shape: (19697, 12, 1)
# targets shape: (19697, 1)
# val dataset:
# samples shape: (19711, 12, 1)
# targets shape: (19711, 1)

# %%
print(raw_data.shape[-1])
# Out:
# 1

# %%
# Import
from tensorflow import keras
from keras.layers import SpatialDropout1D, Bidirectional
from tensorflow.keras import layers , regularizers
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D, Dense, MaxPooling1D, Flatten, Input
from tensorflow.keras.callbacks import EarlyStopping

opt = keras.optimizers.Adam(learning_rate=0.015)

# define model
model = Sequential()
model.add(LSTM(units=64, input_shape=(sequence_length, 1)))
model.add(Dropout(0.2)) # add dropout layer with a rate of 0.2
model.add(Dense(units=64))
model.add(Dropout(0.2)) # add dropout layer with a rate of 0.2
model.add(Dense(units=32))
model.add(Dense(units=1))
model.compile(loss='mae' , optimizer=opt , metrics=['mae'])

# Define callbacks using the best model only
best_model_callback = ModelCheckpoint("best_model.h5", monitor='val_loss', save_best_only=True)
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# Train model
history = model.fit(train_dataset, epochs=60, batch_size = 128, validation_data=val_dataset, callbacks=[best_model_callback])

# Evaluate model on test set
model = keras.models.load_model("best_model.h5")
test_loss, test_mae = model.evaluate(test_dataset)

# Print test metrics
print("Test Loss:", test_loss)
print("Test MAE:", test_mae)
# Out:
# Epoch 1/60
# 1/1 [==============================] - 12s 12s/step - loss: 0.8301 - mae: 0.8301 - val_loss: 0.8023 - val_mae: 0.8023
# Epoch 2/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.8244 - mae: 0.8244 - val_loss: 0.7018 - val_mae: 0.7018
# Epoch 3/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.7100 - mae: 0.7100 - val_loss: 0.7248 - val_mae: 0.7248
# Epoch 4/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.7362 - mae: 0.7362 - val_loss: 0.6619 - val_mae: 0.6619
# Epoch 5/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6736 - mae: 0.6736 - val_loss: 0.6143 - val_mae: 0.6143
# Epoch 6/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6269 - mae: 0.6269 - val_loss: 0.5760 - val_mae: 0.5760
# Epoch 7/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6132 - mae: 0.6132 - val_loss: 0.5515 - val_mae: 0.5515
# Epoch 8/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5887 - mae: 0.5887 - val_loss: 0.5050 - val_mae: 0.5050
# Epoch 9/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5317 - mae: 0.5317 - val_loss: 0.5027 - val_mae: 0.5027
# Epoch 10/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5245 - mae: 0.5245 - val_loss: 0.4699 - val_mae: 0.4699
# Epoch 11/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5014 - mae: 0.5014 - val_loss: 0.4298 - val_mae: 0.4298
# Epoch 12/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4820 - mae: 0.4820 - val_loss: 0.4354 - val_mae: 0.4354
# Epoch 13/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4926 - mae: 0.4926 - val_loss: 0.4139 - val_mae: 0.4139
# Epoch 14/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4686 - mae: 0.4686 - val_loss: 0.4240 - val_mae: 0.4240
# Epoch 15/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4684 - mae: 0.4684 - val_loss: 0.4151 - val_mae: 0.4151
# Epoch 16/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4509 - mae: 0.4509 - val_loss: 0.4068 - val_mae: 0.4068
# Epoch 17/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4390 - mae: 0.4390 - val_loss: 0.3992 - val_mae: 0.3992
# Epoch 18/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4380 - mae: 0.4380 - val_loss: 0.3828 - val_mae: 0.3828
# Epoch 19/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4256 - mae: 0.4256 - val_loss: 0.3767 - val_mae: 0.3767
# Epoch 20/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4107 - mae: 0.4107 - val_loss: 0.3775 - val_mae: 0.3775
# Epoch 21/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4075 - mae: 0.4075 - val_loss: 0.3475 - val_mae: 0.3475
# Epoch 22/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3874 - mae: 0.3874 - val_loss: 0.3755 - val_mae: 0.3755
# Epoch 23/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4213 - mae: 0.4213 - val_loss: 0.3890 - val_mae: 0.3890
# Epoch 24/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4286 - mae: 0.4286 - val_loss: 0.3677 - val_mae: 0.3677
# Epoch 25/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3929 - mae: 0.3929 - val_loss: 0.3569 - val_mae: 0.3569
# Epoch 26/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3875 - mae: 0.3875 - val_loss: 0.3222 - val_mae: 0.3222
# Epoch 27/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3648 - mae: 0.3648 - val_loss: 0.3565 - val_mae: 0.3565
# Epoch 28/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3931 - mae: 0.3931 - val_loss: 0.3211 - val_mae: 0.3211
# Epoch 29/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3614 - mae: 0.3614 - val_loss: 0.3204 - val_mae: 0.3204
# Epoch 30/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3531 - mae: 0.3531 - val_loss: 0.3325 - val_mae: 0.3325
# Epoch 31/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3627 - mae: 0.3627 - val_loss: 0.2966 - val_mae: 0.2966
# Epoch 32/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3412 - mae: 0.3412 - val_loss: 0.2914 - val_mae: 0.2914
# Epoch 33/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3420 - mae: 0.3420 - val_loss: 0.3012 - val_mae: 0.3012
# Epoch 34/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3438 - mae: 0.3438 - val_loss: 0.2894 - val_mae: 0.2894
# Epoch 35/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3264 - mae: 0.3264 - val_loss: 0.3061 - val_mae: 0.3061
# Epoch 36/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3340 - mae: 0.3340 - val_loss: 0.2949 - val_mae: 0.2949
# Epoch 37/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3245 - mae: 0.3245 - val_loss: 0.2738 - val_mae: 0.2738
# Epoch 38/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3138 - mae: 0.3138 - val_loss: 0.2791 - val_mae: 0.2791
# Epoch 39/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3228 - mae: 0.3228 - val_loss: 0.2787 - val_mae: 0.2787
# Epoch 40/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3154 - mae: 0.3154 - val_loss: 0.2711 - val_mae: 0.2711
# Epoch 41/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3073 - mae: 0.3073 - val_loss: 0.2789 - val_mae: 0.2789
# Epoch 42/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3101 - mae: 0.3101 - val_loss: 0.2758 - val_mae: 0.2758
# Epoch 43/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3049 - mae: 0.3049 - val_loss: 0.2630 - val_mae: 0.2630
# Epoch 44/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3003 - mae: 0.3003 - val_loss: 0.2598 - val_mae: 0.2598
# Epoch 45/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2978 - mae: 0.2978 - val_loss: 0.2539 - val_mae: 0.2539
# Epoch 46/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2910 - mae: 0.2910 - val_loss: 0.2575 - val_mae: 0.2575
# Epoch 47/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2916 - mae: 0.2916 - val_loss: 0.2593 - val_mae: 0.2593
# Epoch 48/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2894 - mae: 0.2894 - val_loss: 0.2573 - val_mae: 0.2573
# Epoch 49/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2928 - mae: 0.2928 - val_loss: 0.2855 - val_mae: 0.2855
# Epoch 50/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3119 - mae: 0.3119 - val_loss: 0.2489 - val_mae: 0.2489
# Epoch 51/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2826 - mae: 0.2826 - val_loss: 0.2700 - val_mae: 0.2700
# Epoch 52/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3054 - mae: 0.3054 - val_loss: 0.3149 - val_mae: 0.3149
# Epoch 53/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3323 - mae: 0.3323 - val_loss: 0.2921 - val_mae: 0.2921
# Epoch 54/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3137 - mae: 0.3137 - val_loss: 0.2588 - val_mae: 0.2588
# Epoch 55/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2982 - mae: 0.2982 - val_loss: 0.2688 - val_mae: 0.2688
# Epoch 56/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3083 - mae: 0.3083 - val_loss: 0.2541 - val_mae: 0.2541
# Epoch 57/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2836 - mae: 0.2836 - val_loss: 0.2749 - val_mae: 0.2749
# Epoch 58/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2984 - mae: 0.2984 - val_loss: 0.2393 - val_mae: 0.2393
# Epoch 59/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2741 - mae: 0.2741 - val_loss: 0.2554 - val_mae: 0.2554
# Epoch 60/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2934 - mae: 0.2934 - val_loss: 0.2335 - val_mae: 0.2335
# 1/1 [==============================] - 1s 1s/step - loss: 0.2370 - mae: 0.2370
# Test Loss: 0.237017422914505
# Test MAE: 0.237017422914505

# %%
import matplotlib.pyplot as plt
# Plot training and validation Loss
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, "bo", label="Training LOSS")
plt.plot(epochs, val_loss, "r", label="Validation LOSS")
plt.title("Training and validation LOSS")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Plot training and validation MAE
mae = history.history["mae"]
val_mae = history.history["val_mae"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, mae, "bo", label="Training MAE")
plt.plot(epochs, val_mae, "r", label="Validation MAE")
plt.title("Training and validation MAE")
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                16896
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 23,169
# Trainable params: 23,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Get the predicted values for the test dataset
y_pred = model.predict(test_dataset)

# Plot the predicted values
plt.figure(figsize=(15, 5))
plt.plot(y_pred, label='Predicted', color='red')
plt.xlabel('Time')
plt.ylabel('Eload')
plt.title('Predicted Eload Values')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
len(y_pred)
# Out:
# 19697

# %%
lenpred = len(y_pred)
lenpred
# Out:
# 19697

# %%
org_targets = raw_data[num_train_samples + num_val_samples:]

# %%
len(org_targets)
# Out:
# 19722

# %%
left_crop = (sequence_length + horizon) * sampling_rate
right_crop = ( (sequence_length - 1) * sampling_rate) - 1
midtargets = org_targets[left_crop:-right_crop]
print("midtargets shape:", midtargets.shape)
plt.figure(figsize=(10,5))
plt.plot(range(lenpred), midtargets)
# Out:
# midtargets shape: (19697, 1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_pred[6000:6500], "r", label="PREDICTIONS")
plt.plot(midtargets[6000:6500], "b", label="TARGETS")
plt.title("PREDICTIONS (in red) and TARGETS (in blue)")
plt.legend()
plt.show()

# %%
# REVERTING (on predictions) THE "NORMALIZATION" of the targets
# TO YIELD THE "EFFECTIVE PREDICTIONS" (EFFpredictions)
# EFFpredictions1 = predictions * 585
EFFpredictions1 = np.asarray(y_pred * 585)
EFFpredictions2 = EFFpredictions1.flatten()

# %%
EFFpredictions2
# Out:
# array([  14.699361,  123.812126, -196.61845 , ...,  590.6259  ,
#         406.5593  ,  275.6714  ], dtype=float32)

# %%
MEANV = (np.ones(lenpred,)) * 3310
MEANV
# Out:
# array([3310., 3310., 3310., ..., 3310., 3310., 3310.])

# %%
EFFpredictions = EFFpredictions2 + MEANV
EFFpredictions
# Out:
# array([3324.69936085, 3433.81212616, 3113.38154602, ..., 3900.62591553,
#        3716.55929565, 3585.67138672])

# %%
EFFpredictions.shape
# Out:
# (19697,)

# %%
plt.plot(range(lenpred), EFFpredictions,'r')

# %%
NOSCALEeloadTESTtargets= eload[num_train_samples + num_val_samples:]
# Now cropping
midNOSCALEeload = NOSCALEeloadTESTtargets[left_crop:-right_crop]
print("midNOSCALEeload shape:", midNOSCALEeload.shape)
plt.plot(range(lenpred), midNOSCALEeload)
# Out:
# midNOSCALEeload shape: (19697,)

# %%
# Now overlay plot of predictions and targets in the same interval
plt.figure(figsize=(12, 6))
plt.plot(EFFpredictions[6000:6500], "r", label="EFF PREDICTIONS")
plt.plot(midNOSCALEeload[6000:6500], "b", label="TARGETS")
plt.title("EFF PREDICTIONS (in red) and TARGETS (in blue)")
plt.legend()
plt.show()

# %%
EFFECTIVE_MAE = np.mean(np.abs(midNOSCALEeload - EFFpredictions))
print(f"EFFECTIVE real-scale MAE: {EFFECTIVE_MAE:.2f}")
# Out:
# EFFECTIVE real-scale MAE: 198.14
