# %% [markdown]
# # **PART III-B : 2-input predictor for a 6-hour horizon**

# %% [markdown]
# # dataset
# **Retrieving the  GEFCom2014 (E, V2) Data**
#
# The data in this project is taken from the GEFCom2014 forecasting competition. It consists of hourly electricity load ("eload") and temperature ("tempf") values for a USA city. *italicized text*
# The data will be brought into the Colab session from an internet repository, aand the extracted Ecel file will be used to create a comma-seprated-value (csv) text file, similar to the one in Chapter 10 of te textbook.

# %%
import numpy as np 
import pandas as pd
import os
import shutil
import matplotlib.pyplot as plt
# from common.utils import load_data, extract_data, download_file
# %matplotlib inline

# !wget https://mlftsfwp.blob.core.windows.net/mlftsfwp/GEFCom2014.zip
# !wget https://www.dropbox.com/s/pqenrr2mcvl0hk9/GEFCom2014.zip
# Out:
# --2023-04-28 12:29:34--  https://www.dropbox.com/s/pqenrr2mcvl0hk9/GEFCom2014.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.4.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.4.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/pqenrr2mcvl0hk9/GEFCom2014.zip [following]
# --2023-04-28 12:29:34--  https://www.dropbox.com/s/raw/pqenrr2mcvl0hk9/GEFCom2014.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com/cd/0/inline/B7DpWcN8PYv6s95M9NiWJ0urPGCqIT120NPVBCl5Jy3T1xLDmZ2yi2GPQHNEeuukI5CCAFLfrxcmSgYYO2GfAmEdCR3qF469d9QW3WCb89R7ImjEXwCYvACmoZUT8c1P67JiGGqcwbq-2iz9xX2uZHbQFtrAML3TjECoX47PS0apZg/file# [following]
# --2023-04-28 12:29:35--  https://uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com/cd/0/inline/B7DpWcN8PYv6s95M9NiWJ0urPGCqIT120NPVBCl5Jy3T1xLDmZ2yi2GPQHNEeuukI5CCAFLfrxcmSgYYO2GfAmEdCR3qF469d9QW3WCb89R7ImjEXwCYvACmoZUT8c1P67JiGGqcwbq-2iz9xX2uZHbQFtrAML3TjECoX47PS0apZg/file
# Resolving uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com (uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com)... 162.125.8.15, 2620:100:6018:15::a27d:30f
# Connecting to uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com (uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com)|162.125.8.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/B7B8-xWAds7pAELpRdQ8pttDEJ9WuqRwUo9qlvN2qGwmzcrNEKBzbuPxD5AgPB97M9h5mNXb898bGaP6O62mkgEdQH99nmWvoJxfTrKixdQmoRH4_zRfebbqlaVZvVi76tFUlN4W0GmhGWulKO_Je30ohrLgK2ZXsP9QNwPLfqfSixsX_Gd7RKHJDTBEdW9j1yKCn2egYy1OjKaaWzfaRS4NbcQsexp5CragsErl72R7RXc4jTHKLONFXvtc9mj4MJ68J5BaabA9H1zgPuhYnL4tAgAgQC_v5CuZRWFTRXBudidnTyu0dK6BRW8MeRnIopAd5zY3fn3gXSNF49j1mUo-7RGGtlZWUFdZnlBg42p9A_Wnqbylkrp0gbiDR4yICY04-SQ1Jm1v16SmH4PSBODUGTA_q4neHtz-Gpsww4EGuQ/file [following]
# --2023-04-28 12:29:36--  https://uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com/cd/0/inline2/B7B8-xWAds7pAELpRdQ8pttDEJ9WuqRwUo9qlvN2qGwmzcrNEKBzbuPxD5AgPB97M9h5mNXb898bGaP6O62mkgEdQH99nmWvoJxfTrKixdQmoRH4_zRfebbqlaVZvVi76tFUlN4W0GmhGWulKO_Je30ohrLgK2ZXsP9QNwPLfqfSixsX_Gd7RKHJDTBEdW9j1yKCn2egYy1OjKaaWzfaRS4NbcQsexp5CragsErl72R7RXc4jTHKLONFXvtc9mj4MJ68J5BaabA9H1zgPuhYnL4tAgAgQC_v5CuZRWFTRXBudidnTyu0dK6BRW8MeRnIopAd5zY3fn3gXSNF49j1mUo-7RGGtlZWUFdZnlBg42p9A_Wnqbylkrp0gbiDR4yICY04-SQ1Jm1v16SmH4PSBODUGTA_q4neHtz-Gpsww4EGuQ/file
# Reusing existing connection to uc00d7a7404e4584fc7832bdbcd5.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 126360077 (121M) [application/zip]
# Saving to: ‘GEFCom2014.zip’
#
# GEFCom2014.zip      100%[===================>] 120.51M   158MB/s    in 0.8s
#
# 2023-04-28 12:29:37 (158 MB/s) - ‘GEFCom2014.zip’ saved [126360077/126360077]

# %%
# !ls -l 
# !unzip GEFCom2014.zip
# Out:
# Archive:  GEFCom2014.zip
#    creating: GEFCom2014 Data/
#  extracting: GEFCom2014 Data/GEFCom2014-S_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-W_V2.zip
#   inflating: GEFCom2014 Data/READ ME_V2.txt
#   inflating: GEFCom2014 Data/Provisional_Leaderboard_V2.xlsx
#  extracting: GEFCom2014 Data/GEFCom2014-L_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-E_V2.zip
#  extracting: GEFCom2014 Data/GEFCom2014-P_V2.zip

# %%
# !ls -l
# Out:
# total 123408
# drwxrwxr-x 2 root root      4096 Feb 11  2016 'GEFCom2014 Data'
# -rw-r--r-- 1 root root 126360077 Apr 28 12:29  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %%
# !ls -l 'GEFCom2014 Data'/
# Out:
# total 123420
# -rw-rw-r-- 1 root root  2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-rw-r-- 1 root root  2599214 Feb 11  2016  GEFCom2014-L_V2.zip
# -rw-rw-r-- 1 root root  3338992 Feb 11  2016  GEFCom2014-P_V2.zip
# -rw-rw-r-- 1 root root 36734790 Feb 11  2016  GEFCom2014-S_V2.zip
# -rw-rw-r-- 1 root root 81149634 Feb 11  2016  GEFCom2014-W_V2.zip
# -rw-rw-r-- 1 root root   195932 Feb 11  2016  Provisional_Leaderboard_V2.xlsx
# -rw-rw-r-- 1 root root      389 Feb 11  2016 'READ ME_V2.txt'

# %% [markdown]
# ** We are interested in GEFCom2014-E_V2.zip**

# %%
# Let's bring it to the top level before unzipping it
# !mv  'GEFCom2014 Data'/GEFCom2014-E_V2.zip  ./

# %%
# !unzip GEFCom2014-E_V2.zip
# Out:
# Archive:  GEFCom2014-E_V2.zip
#   inflating: GEFCom2014-E.xlsx

# %%
# We can now verify that we hot the file GEFCom2014-E.xlsx
# !ls -l
# Out:
# total 128100
# drwxrwxr-x 2 root root      4096 Apr 28 12:29 'GEFCom2014 Data'
# -rw-rw-r-- 1 root root   2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-r--r-- 1 root root   2452214 Jan 25  2016  GEFCom2014-E.xlsx
# -rw-r--r-- 1 root root 126360077 Apr 28 12:29  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %% [markdown]
# ***We have GEFCom2014-E.xlsx***

# %% [markdown]
# This script will "translate" the .xlsx file to a .cvs file, so that the initial situation is the same as for the Jena temperature example from Chapter 10 of textbook - IN THIS PROCESS WE WILL ALSO REMOVE THE MLTIPLE INITIAL LINES THAT DO NOT HAVE LOAD VALUES (this is done through the "skip_rows" parameter)

# %%
# CONVERT GEFCom2014-E.xlsx to a PANDAS DATAFRAME called GEFDF
# import pandas as pd

GEFDF = pd.read_excel('GEFCom2014-E.xlsx', skiprows=range(1, 17545), dtype = {'A':np.int32  ,'B':np.int8   ,'C':np.int32  ,'D':np.float64}, index_col = None )

# %%
# We can "see" the Pandas DataFrame (called GEFDF) that has been obtained
print(GEFDF)
# Out:
#             Date  Hour    load          T
# 0     2006-01-01     1  3010.0  22.666667
# 1     2006-01-01     2  2853.0  20.666667
# 2     2006-01-01     3  2758.0  21.333333
# 3     2006-01-01     4  2705.0  19.000000
# 4     2006-01-01     5  2709.0  19.333333
# ...          ...   ...     ...        ...
# 78883 2014-12-31    20  4012.0  18.000000
# 78884 2014-12-31    21  3856.0  16.666667
# 78885 2014-12-31    22  3671.0  17.000000
# 78886 2014-12-31    23  3499.0  15.333333
# 78887 2014-12-31    24  3345.0  15.333333
#
# [78888 rows x 4 columns]

# %%
# Now writing out the GEFDF dataframe to a text (csv) file
GEFDF.to_csv('GEF14.csv',  encoding='utf-8', index=False, header=True, columns=['Hour','load','T'],line_terminator='\n' )
with open('GEF14.csv') as f:
    lines = f.readlines()
    last = len(lines) - 1
    lines[last] = lines[last].replace('\r','').replace('\n','')
with open('GEF14.csv', 'w') as wr:
    wr.writelines(lines)
# Out:
# <ipython-input-10-95d21a26e29b>:2: FutureWarning: the 'line_terminator'' keyword is deprecated, use 'lineterminator' instead.
#   GEFDF.to_csv('GEF14.csv',  encoding='utf-8', index=False, header=True, columns=['Hour','load','T'],line_terminator='\n' )

# %%
# verifying we have created the csv file GEF14.csv
# !ls -l ./
# Out:
# total 129640
# -rw-r--r-- 1 root root   1573348 Apr 28 12:29  GEF14.csv
# drwxrwxr-x 2 root root      4096 Apr 28 12:29 'GEFCom2014 Data'
# -rw-rw-r-- 1 root root   2348089 Feb 11  2016  GEFCom2014-E_V2.zip
# -rw-r--r-- 1 root root   2452214 Jan 25  2016  GEFCom2014-E.xlsx
# -rw-r--r-- 1 root root 126360077 Apr 28 12:29  GEFCom2014.zip
# drwxr-xr-x 1 root root      4096 Apr 26 17:36  sample_data

# %% [markdown]
# From this point onwards, the preparation is similar as for the Jena temperature prediction case from the book but the columns in this file are just:

# %% [markdown]
# hour( 1 to 24) ; LOAD (e.g., 4012.0 ) ; TEMP (in oF ,  e.g., 86.5)

# %% [markdown]
# **Inspecting the data of the GEFC14.csv FILE**

# %% [markdown]
# This will separate the heade from the rest, whicj will be kept in "lines"

# %%
# THIS CODE CELL IS ESSENTIALLY THE SAME AS IN THE EXAMPLE FROM CH. 10 IN BOOK
import os
fname = os.path.join("GEF14.csv")

with open(fname) as f:
    data = f.read()

lines = data.split("\n")
header = lines[0].split(",")
lines = lines[1:]
print(header)
print(len(lines))
# Out:
# ['Hour', 'load', 'T']
# 78888

# %% [markdown]
# **Parsing the data**

# %% [markdown]
# We will separate temperatures in tempf, loads in eload and both in raw_data (Hour will be ignored)

# %%
# VERY SIMILAR TO THE CORRESPONDING C0DE CELL FROM CHAPTER 10 IN BOOK
# eload (electric load) is the timeseries we will predict
# tempf (temperature in Fahrenheit) is the temperature at the same time
# import numpy as np
eload = np.zeros((len(lines),))
tempf = np.zeros((len(lines),))
raw_data = np.zeros((len(lines), len(header)-1))  
raw_data2 = np.zeros((len(lines), len(header)-2))  #chgd )-1  to )-2 to also
# remove the HOUR column, in addition to the DATE column
print(len(lines))
#raw_data = np.column_stack((eload, tempf))

for m in range(78888):
    thisline  = lines[m]
    values = [float(x) for x in thisline.split(",")[1:]]
    eload[m] = values[0]         #Captures JUST E LOAD
    tempf[m] = values[1]            #Captures JUST TEMPF
    raw_data2[m] = values[0]         #Like this, raw_data Captures JUST E LOAD
    raw_data[m, :] = values[:]   # Like this, raw_data CAPTURES BOTH
# Out:
# 78888

# %% [markdown]
# **Plotting the eload timeseries**

# %%
from matplotlib import pyplot as plt
plt.plot(range(len(eload)), eload)

# %%
plt.plot(range(len(tempf)), tempf)

# %% [markdown]
# **THIS IS THE BEGINNING OF THE ACTUAL SOLUTION**

# %% [markdown]
# **Computing the number of samples we'll use for each data split**

# %%
num_train_samples = int(0.5 * len(raw_data))
num_val_samples = int(0.25 * len(raw_data))
num_test_samples = len(raw_data) - num_train_samples - num_val_samples
print("num_train_samples:", num_train_samples)
print("num_val_samples:", num_val_samples)
print("num_test_samples:", num_test_samples)
# Out:
# num_train_samples: 39444
# num_val_samples: 19722
# num_test_samples: 19722

# %% [markdown]
# ### Preparing the data

# %%
# Display the ELOAD for the first 10 days
plt.plot(range(240),eload[:240])

# %%
# Display the tempf for the first 10 days
plt.plot(range(240),tempf[:240])

# %% [markdown]
# **Normalizing the data**

# %%
mean = raw_data[:num_train_samples].mean(axis=0)
raw_data -= mean
std = raw_data[:num_train_samples].std(axis=0)
raw_data /= std

# %%
mean2 = raw_data2[:num_train_samples].mean(axis=0)
raw_data2 -= mean2
std2 = raw_data2[:num_train_samples].std(axis=0)
raw_data2 /= std2

# %%
mean
# Out:
# array([3310.41855542,   46.73044485])

# %%
std
# Out:
# array([585.83380329,  18.95383242])

# %%
mean2
# Out:
# array([3310.41855542])

# %%
std2
# Out:
# array([585.83380329])

# %%
raw_data2
# Out:
# array([[-0.51280509],
#        [-0.78079918],
#        [-0.94296122],
#        ...,
#        [ 0.61550126],
#        [ 0.32190263],
#        [ 0.05902945]])

# %% [markdown]
# # Instantiating datasets for training, validation, and testing for 6 hour two input

# %%
# LETS JUST USE ELOAD TO FORECAST ELOAD
# THIS TIME, ( 2-input case)
from tensorflow import keras

horizon = 6     # Num. of hours ahead for forecast
sampling_rate = 1
sequence_length = 24
delay = sampling_rate * (sequence_length + horizon - 1) 
batch_size = 128

train_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],    
    targets=raw_data2[delay:], # This would used "Normalized Targets"
   # targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,                  #changed to false JUST FOR VERIF
    batch_size= num_train_samples,
    start_index=0,
    end_index=num_train_samples)

val_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],    # changed from raw_data to just eload not really
    targets=raw_data2[delay:],  # This would used "Normalized Targets"
    #targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=True,
    batch_size=num_val_samples,
    start_index=num_train_samples,
    end_index=num_train_samples + num_val_samples)

test_dataset = keras.utils.timeseries_dataset_from_array(
    raw_data[:-delay],     # changed from raw_data to just eload
    targets=raw_data2[delay:],  # This would used "Normalized Targets"
    #targets=eload[delay:], # This would used "Not-normalized eload targets"
    sampling_rate=sampling_rate,
    sequence_length=sequence_length,
    shuffle=False,
    batch_size=num_test_samples,
    start_index=num_train_samples + num_val_samples)

# %%
max_eload=0
min_eload=np.inf
for x, y in test_dataset:
    eload_values = y  # extract the eload values from the target array
    max_eload_in_batch = np.max(eload_values)
    if max_eload_in_batch > max_eload:
      max_eload = max_eload_in_batch

    min_eload_in_batch = np.min(eload_values)
    if min_eload_in_batch < min_eload:
        min_eload = min_eload_in_batch

full_range_eload = max_eload - min_eload


print("Max eload in the test set: ", max_eload)

print("Min eload in the test set: ", min_eload)

print("Full range of eload in the test set: ", full_range_eload)
# Out:
# Max eload in the test set:  3.266423743130643
# Min eload in the test set:  -2.2726898788595946
# Full range of eload in the test set:  5.5391136219902375

# %%
for samples, targets in train_dataset:
    print("train dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
for samples, targets in test_dataset:
    print("test dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
for samples, targets in val_dataset:
    print("val dataset:")
    print("samples shape:", samples.shape)
    print("targets shape:", targets.shape)
    break
# Out:
# train dataset:
# samples shape: (39421, 24, 2)
# targets shape: (39421, 1)
# test dataset:
# samples shape: (19670, 24, 2)
# targets shape: (19670, 1)
# val dataset:
# samples shape: (19699, 24, 2)
# targets shape: (19699, 1)

# %%
print(raw_data.shape[-1])
# Out:
# 2

# %%
# Import
from tensorflow import keras
from keras.layers import SpatialDropout1D, Bidirectional
from tensorflow.keras import layers , regularizers
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import Conv1D, Dense, MaxPooling1D, Flatten, Input
from tensorflow.keras.callbacks import EarlyStopping

opt = keras.optimizers.Adam(learning_rate=0.015)

# define model
model = Sequential()
model.add(LSTM(units=64, input_shape=(sequence_length, 2)))
model.add(Dropout(0.2)) # add dropout layer with a rate of 0.2
model.add(Dense(units=64))
model.add(Dropout(0.2)) # add dropout layer with a rate of 0.2
model.add(Dense(units=32))
model.add(Dense(units=1))
model.compile(loss='mae' , optimizer=opt , metrics=['mae'])

# Define callbacks using the best model only
best_model_callback = ModelCheckpoint("best_model.h5", monitor='val_loss', save_best_only=True)
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# Train model
history = model.fit(train_dataset, epochs=60, batch_size = 128, validation_data=val_dataset, callbacks=[best_model_callback])

# Evaluate model on test set
model = keras.models.load_model("best_model.h5")
test_loss, test_mae = model.evaluate(test_dataset)

# Print test metrics
print("Test Loss:", test_loss)
print("Test MAE:", test_mae)
# Out:
# Epoch 1/60
# 1/1 [==============================] - 12s 12s/step - loss: 0.8688 - mae: 0.8688 - val_loss: 1.3141 - val_mae: 1.3141
# Epoch 2/60
# 1/1 [==============================] - 2s 2s/step - loss: 1.2023 - mae: 1.2023 - val_loss: 0.8462 - val_mae: 0.8462
# Epoch 3/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.8663 - mae: 0.8663 - val_loss: 0.8311 - val_mae: 0.8311
# Epoch 4/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.8469 - mae: 0.8469 - val_loss: 0.8000 - val_mae: 0.8000
# Epoch 5/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.7892 - mae: 0.7892 - val_loss: 0.8156 - val_mae: 0.8156
# Epoch 6/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.7781 - mae: 0.7781 - val_loss: 0.7284 - val_mae: 0.7284
# Epoch 7/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.7101 - mae: 0.7101 - val_loss: 0.5842 - val_mae: 0.5842
# Epoch 8/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6123 - mae: 0.6123 - val_loss: 0.6755 - val_mae: 0.6755
# Epoch 9/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6980 - mae: 0.6980 - val_loss: 0.5687 - val_mae: 0.5687
# Epoch 10/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5922 - mae: 0.5922 - val_loss: 0.6396 - val_mae: 0.6396
# Epoch 11/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.6459 - mae: 0.6459 - val_loss: 0.5720 - val_mae: 0.5720
# Epoch 12/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5696 - mae: 0.5696 - val_loss: 0.4788 - val_mae: 0.4788
# Epoch 13/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4995 - mae: 0.4995 - val_loss: 0.4939 - val_mae: 0.4939
# Epoch 14/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.5289 - mae: 0.5289 - val_loss: 0.4369 - val_mae: 0.4369
# Epoch 15/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4627 - mae: 0.4627 - val_loss: 0.4338 - val_mae: 0.4338
# Epoch 16/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4533 - mae: 0.4533 - val_loss: 0.4489 - val_mae: 0.4489
# Epoch 17/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4685 - mae: 0.4685 - val_loss: 0.3962 - val_mae: 0.3962
# Epoch 18/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4220 - mae: 0.4220 - val_loss: 0.3778 - val_mae: 0.3778
# Epoch 19/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4063 - mae: 0.4063 - val_loss: 0.3865 - val_mae: 0.3865
# Epoch 20/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4125 - mae: 0.4125 - val_loss: 0.3833 - val_mae: 0.3833
# Epoch 21/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4099 - mae: 0.4099 - val_loss: 0.3686 - val_mae: 0.3686
# Epoch 22/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3870 - mae: 0.3870 - val_loss: 0.3890 - val_mae: 0.3890
# Epoch 23/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.4110 - mae: 0.4110 - val_loss: 0.3331 - val_mae: 0.3331
# Epoch 24/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3555 - mae: 0.3555 - val_loss: 0.3629 - val_mae: 0.3629
# Epoch 25/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3875 - mae: 0.3875 - val_loss: 0.3347 - val_mae: 0.3347
# Epoch 26/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3758 - mae: 0.3758 - val_loss: 0.3010 - val_mae: 0.3010
# Epoch 27/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3270 - mae: 0.3270 - val_loss: 0.3328 - val_mae: 0.3328
# Epoch 28/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3543 - mae: 0.3543 - val_loss: 0.2911 - val_mae: 0.2911
# Epoch 29/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3273 - mae: 0.3273 - val_loss: 0.2922 - val_mae: 0.2922
# Epoch 30/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3250 - mae: 0.3250 - val_loss: 0.2991 - val_mae: 0.2991
# Epoch 31/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3266 - mae: 0.3266 - val_loss: 0.2838 - val_mae: 0.2838
# Epoch 32/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3180 - mae: 0.3180 - val_loss: 0.2763 - val_mae: 0.2763
# Epoch 33/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3077 - mae: 0.3077 - val_loss: 0.2874 - val_mae: 0.2874
# Epoch 34/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3113 - mae: 0.3113 - val_loss: 0.2769 - val_mae: 0.2769
# Epoch 35/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3046 - mae: 0.3046 - val_loss: 0.2667 - val_mae: 0.2667
# Epoch 36/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3002 - mae: 0.3002 - val_loss: 0.2674 - val_mae: 0.2674
# Epoch 37/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2973 - mae: 0.2973 - val_loss: 0.2587 - val_mae: 0.2587
# Epoch 38/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2898 - mae: 0.2898 - val_loss: 0.2660 - val_mae: 0.2660
# Epoch 39/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3019 - mae: 0.3019 - val_loss: 0.2779 - val_mae: 0.2779
# Epoch 40/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.3022 - mae: 0.3022 - val_loss: 0.2569 - val_mae: 0.2569
# Epoch 41/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2873 - mae: 0.2873 - val_loss: 0.2536 - val_mae: 0.2536
# Epoch 42/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2870 - mae: 0.2870 - val_loss: 0.2823 - val_mae: 0.2823
# Epoch 43/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2972 - mae: 0.2972 - val_loss: 0.2463 - val_mae: 0.2463
# Epoch 44/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2767 - mae: 0.2767 - val_loss: 0.2535 - val_mae: 0.2535
# Epoch 45/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2879 - mae: 0.2879 - val_loss: 0.2606 - val_mae: 0.2606
# Epoch 46/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2820 - mae: 0.2820 - val_loss: 0.2506 - val_mae: 0.2506
# Epoch 47/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2742 - mae: 0.2742 - val_loss: 0.2475 - val_mae: 0.2475
# Epoch 48/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2828 - mae: 0.2828 - val_loss: 0.2609 - val_mae: 0.2609
# Epoch 49/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2811 - mae: 0.2811 - val_loss: 0.2404 - val_mae: 0.2404
# Epoch 50/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2679 - mae: 0.2679 - val_loss: 0.2445 - val_mae: 0.2445
# Epoch 51/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2794 - mae: 0.2794 - val_loss: 0.2611 - val_mae: 0.2611
# Epoch 52/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2784 - mae: 0.2784 - val_loss: 0.2402 - val_mae: 0.2402
# Epoch 53/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2655 - mae: 0.2655 - val_loss: 0.2497 - val_mae: 0.2497
# Epoch 54/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2806 - mae: 0.2806 - val_loss: 0.2555 - val_mae: 0.2555
# Epoch 55/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2736 - mae: 0.2736 - val_loss: 0.2419 - val_mae: 0.2419
# Epoch 56/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2653 - mae: 0.2653 - val_loss: 0.2495 - val_mae: 0.2495
# Epoch 57/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2797 - mae: 0.2797 - val_loss: 0.2444 - val_mae: 0.2444
# Epoch 58/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2641 - mae: 0.2641 - val_loss: 0.2391 - val_mae: 0.2391
# Epoch 59/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2624 - mae: 0.2624 - val_loss: 0.2397 - val_mae: 0.2397
# Epoch 60/60
# 1/1 [==============================] - 2s 2s/step - loss: 0.2723 - mae: 0.2723 - val_loss: 0.2335 - val_mae: 0.2335
# 1/1 [==============================] - 1s 1s/step - loss: 0.2370 - mae: 0.2370
# Test Loss: 0.23702189326286316
# Test MAE: 0.23702189326286316

# %%
import matplotlib.pyplot as plt
# Plot training and validation Loss
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, "bo", label="Training LOSS")
plt.plot(epochs, val_loss, "r", label="Validation LOSS")
plt.title("Training and validation LOSS")
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Plot training and validation MAE
mae = history.history["mae"]
val_mae = history.history["val_mae"]
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, mae, "bo", label="Training MAE")
plt.plot(epochs, val_mae, "r", label="Validation MAE")
plt.title("Training and validation MAE")
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 64)                17152
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 23,425
# Trainable params: 23,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

# Get the predicted values for the test dataset
y_pred = model.predict(test_dataset)

# Plot the predicted values
plt.figure(figsize=(15, 5))
plt.plot(y_pred, label='Predicted', color='red')
plt.xlabel('Time')
plt.ylabel('Eload')
plt.title('Predicted Eload Values')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 1s 1s/step

# %%
len(y_pred)
# Out:
# 19670

# %%
lenpred = len(y_pred)
lenpred
# Out:
# 19670

# %%
org_targets = raw_data2[num_train_samples + num_val_samples:]

# %%
len(org_targets)
# Out:
# 19722

# %%
left_crop = (sequence_length + horizon) * sampling_rate
right_crop = ( (sequence_length - 1) * sampling_rate) - 1
midtargets = org_targets[left_crop:-right_crop]
print("midtargets shape:", midtargets.shape)
plt.plot(range(lenpred), midtargets)
# Out:
# midtargets shape: (19670, 1)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_pred[6000:6500], "r", label="PREDICTIONS")
plt.plot(midtargets[6000:6500], "b", label="TARGETS")
plt.title("PREDICTIONS (in red) and TARGETS (in blue)")
plt.legend()
plt.show()

# %%
# REVERTING (on predictions) THE "NORMALIZATION" of the targets
# TO YIELD THE "EFFECTIVE PREDICTIONS" (EFFpredictions)
# EFFpredictions1 = predictions * 585
EFFpredictions1 = np.asarray(y_pred * 585)
EFFpredictions2 = EFFpredictions1.flatten()

# %%
EFFpredictions2
# Out:
# array([ 132.46672,  141.56752,  140.12584, ...,  203.37302,  -71.47096,
#        -271.18607], dtype=float32)

# %%
MEANV = (np.ones(lenpred,)) * 3310
MEANV
# Out:
# array([3310., 3310., 3310., ..., 3310., 3310., 3310.])

# %%
EFFpredictions = EFFpredictions2 + MEANV
EFFpredictions
# Out:
# array([3442.46672058, 3451.56752014, 3450.12583923, ..., 3513.37301636,
#        3238.52903748, 3038.81393433])

# %%
EFFpredictions.shape
# Out:
# (19670,)

# %%
plt.plot(range(lenpred), EFFpredictions,'r')

# %%
NOSCALEeloadTESTtargets= eload[num_train_samples + num_val_samples:]
# Now cropping
midNOSCALEeload = NOSCALEeloadTESTtargets[left_crop:-right_crop]
print("midNOSCALEeload shape:", midNOSCALEeload.shape)
plt.plot(range(lenpred), midNOSCALEeload)
# Out:
# midNOSCALEeload shape: (19670,)

# %%
# Now overlay plot of predictions and targets in the same interval
plt.plot(EFFpredictions[6000:6500], "r", label="EFF PREDICTIONS")
plt.plot(midNOSCALEeload[6000:6500], "b", label="TARGETS")
plt.title("EFF PREDICTIONS (in red) and TARGETS (in blue)")
plt.legend()
plt.show()

# %%
EFFECTIVE_MAE = np.mean(np.abs(midNOSCALEeload - EFFpredictions))
print(f"EFFECTIVE real-scale MAE: {EFFECTIVE_MAE:.2f}")
# Out:
# EFFECTIVE real-scale MAE: 158.03
